# %%
# %matplotlib notebook

# %%
# %matplotlib inline

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
from matplotlib.dates import DateFormatter



# Import API key
from config2 import weather_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_keys
city_weather =[]

for x in cities:
    query_url = url + "&q=" + x
    
    # Get weather data
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()        
    print(json.dumps(weather_json, indent=4, sort_keys=True))
    try: 

        weather_dict = {
             'City': x,
             'Lat':weather_json['coord']['lat'],
             'Lng':weather_json['coord']['lon'],
             'Max_Temp':weather_json['main']['temp_max'],
             'Humidity':weather_json['main']['humidity'],
             'Cloudness':weather_json['clouds']['all'],
             'WindSpeed':weather_json['wind']['speed'],
             'Country':weather_json['sys']['country'],
             'Date':weather_json['dt']

                    }
        city_weather.append(weather_dict)

    except Exception:
        print("City not found!")
    
    
    
print(city_weather)
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 8
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -10.8764,
#         "lon": 26.5969
#     },
#     "dt": 1657879051,
#     "id": 923058,
#     "main": {
#         "feels_like": 73.92,
#         "grnd_level": 869,
#         "humidity": 35,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 75.07,
#         "temp_max": 75.07,
#         "temp_min": 75.07
#     },
#     "name": "Kambove",
#     "sys": {
#         "country": "CD",
#         "sunrise": 1657859586,
#         "sunset": 1657901135
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 114,
#         "gust": 7.99,
#         "speed": 7.02
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 60.1432,
#         "lon": -45.2371
#     },
#     "dt": 1657879051,
#     "id": 3421765,
#     "main": {
#         "feels_like": 43.68,
#         "grnd_level": 1000,
#         "humidity": 83,
#         "pressure": 1000,
#         "sea_level": 1000,
#         "temp": 43.68,
#         "temp_max": 43.68,
#         "temp_min": 43.68
#     },
#     "name": "Nanortalik",
#     "rain": {
#         "1h": 0.27
#     },
#     "sys": {
#         "country": "GL",
#         "sunrise": 1657864989,
#         "sunset": 1657930214
#     },
#     "timezone": -7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 160,
#         "gust": 2.66,
#         "speed": 0.65
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 57.79,
#         "lon": -152.4072
#     },
#     "dt": 1657879051,
#     "id": 5866583,
#     "main": {
#         "feels_like": 54.1,
#         "grnd_level": 1004,
#         "humidity": 91,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 54.66,
#         "temp_max": 54.66,
#         "temp_min": 54.66
#     },
#     "name": "Saint Paul Harbor",
#     "sys": {
#         "country": "US",
#         "sunrise": 1657891933,
#         "sunset": 1657954716
#     },
#     "timezone": -28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 204,
#         "gust": 4.14,
#         "speed": 3.98
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 99
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 68.75,
#         "lon": 161.3
#     },
#     "dt": 1657879051,
#     "id": 2126199,
#     "main": {
#         "feels_like": 46.96,
#         "grnd_level": 1015,
#         "humidity": 54,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 49.89,
#         "temp_max": 49.89,
#         "temp_min": 49.89
#     },
#     "name": "Cherskiy",
#     "sys": {
#         "country": "RU",
#         "sunrise": 0,
#         "sunset": 0
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 348,
#         "gust": 8.52,
#         "speed": 7.23
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 98
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -46.1927,
#         "lon": 168.8643
#     },
#     "dt": 1657879051,
#     "id": 6201424,
#     "main": {
#         "feels_like": 38.48,
#         "grnd_level": 1003,
#         "humidity": 98,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 38.48,
#         "temp_max": 38.48,
#         "temp_min": 38.48
#     },
#     "name": "Mataura",
#     "sys": {
#         "country": "NZ",
#         "id": 2008959,
#         "sunrise": 1657830128,
#         "sunset": 1657862299,
#         "type": 2
#     },
#     "timezone": 43200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 304,
#         "gust": 4.45,
#         "speed": 2.86
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 61.7728,
#         "lon": 6.215
#     },
#     "dt": 1657879039,
#     "id": 3140431,
#     "main": {
#         "feels_like": 52.18,
#         "humidity": 71,
#         "pressure": 1012,
#         "temp": 53.76,
#         "temp_max": 56.57,
#         "temp_min": 52.02
#     },
#     "name": "Sandane",
#     "sys": {
#         "country": "NO",
#         "id": 1664,
#         "sunrise": 1657851609,
#         "sunset": 1657918896,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 0,
#         "speed": 2.3
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -7.2597,
#         "lon": -34.9075
#     },
#     "dt": 1657879051,
#     "id": 3385077,
#     "main": {
#         "feels_like": 70.59,
#         "humidity": 100,
#         "pressure": 1014,
#         "temp": 69.26,
#         "temp_max": 69.26,
#         "temp_min": 69.26
#     },
#     "name": "Conde",
#     "sys": {
#         "country": "BR",
#         "id": 8391,
#         "sunrise": 1657873997,
#         "sunset": 1657916248,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 180,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -54.8,
#         "lon": -68.3
#     },
#     "dt": 1657878909,
#     "id": 3833367,
#     "main": {
#         "feels_like": 24.46,
#         "humidity": 80,
#         "pressure": 1027,
#         "temp": 24.46,
#         "temp_max": 24.46,
#         "temp_min": 24.46
#     },
#     "name": "Ushuaia",
#     "sys": {
#         "country": "AR",
#         "id": 8303,
#         "sunrise": 1657889242,
#         "sunset": 1657917032,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 0,
#         "speed": 1.14
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 42.6001,
#         "lon": -73.9662
#     },
#     "dt": 1657879052,
#     "id": 5106841,
#     "main": {
#         "feels_like": 54.79,
#         "humidity": 86,
#         "pressure": 1020,
#         "temp": 55.49,
#         "temp_max": 58.73,
#         "temp_min": 51.26
#     },
#     "name": "Albany",
#     "sys": {
#         "country": "US",
#         "id": 19530,
#         "sunrise": 1657877487,
#         "sunset": 1657931508,
#         "type": 2
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 301,
#         "gust": 3.49,
#         "speed": 3.44
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 33
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -41.8697,
#         "lon": -73.8203
#     },
#     "dt": 1657879052,
#     "id": 3899695,
#     "main": {
#         "feels_like": 32.09,
#         "grnd_level": 1017,
#         "humidity": 83,
#         "pressure": 1023,
#         "sea_level": 1023,
#         "temp": 38.23,
#         "temp_max": 38.23,
#         "temp_min": 38.23
#     },
#     "name": "Ancud",
#     "sys": {
#         "country": "CL",
#         "id": 2043823,
#         "sunrise": 1657887518,
#         "sunset": 1657921406,
#         "type": 2
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 147,
#         "gust": 16.31,
#         "speed": 8.66
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -3.945,
#         "lon": 122.4989
#     },
#     "dt": 1657879052,
#     "id": 1640344,
#     "main": {
#         "feels_like": 75.27,
#         "grnd_level": 1006,
#         "humidity": 96,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 73.69,
#         "temp_max": 73.69,
#         "temp_min": 73.69
#     },
#     "name": "Kendari",
#     "rain": {
#         "1h": 0.11
#     },
#     "sys": {
#         "country": "ID",
#         "sunrise": 1657835903,
#         "sunset": 1657878782
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 232,
#         "gust": 3.11,
#         "speed": 0.29
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -23.1203,
#         "lon": -134.9692
#     },
#     "dt": 1657879052,
#     "id": 4030556,
#     "main": {
#         "feels_like": 67.24,
#         "grnd_level": 1013,
#         "humidity": 77,
#         "pressure": 1016,
#         "sea_level": 1016,
#         "temp": 67.21,
#         "temp_max": 67.21,
#         "temp_min": 67.21
#     },
#     "name": "Rikitea",
#     "sys": {
#         "country": "PF",
#         "sunrise": 1657899624,
#         "sunset": 1657938654
#     },
#     "timezone": -32400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 72,
#         "gust": 8.79,
#         "speed": 8.3
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -42.8794,
#         "lon": 147.3294
#     },
#     "dt": 1657879052,
#     "id": 2163355,
#     "main": {
#         "feels_like": 41.7,
#         "humidity": 83,
#         "pressure": 1015,
#         "temp": 44.87,
#         "temp_max": 46.26,
#         "temp_min": 41.25
#     },
#     "name": "Hobart",
#     "sys": {
#         "country": "AU",
#         "id": 2002195,
#         "sunrise": 1657834645,
#         "sunset": 1657868120,
#         "type": 2
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 330,
#         "speed": 5.75
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 97
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.4187,
#         "lon": 19.2345
#     },
#     "dt": 1657879052,
#     "id": 3366880,
#     "main": {
#         "feels_like": 59.83,
#         "grnd_level": 1022,
#         "humidity": 69,
#         "pressure": 1025,
#         "sea_level": 1025,
#         "temp": 60.8,
#         "temp_max": 60.8,
#         "temp_min": 60.8
#     },
#     "name": "Hermanus",
#     "sys": {
#         "country": "ZA",
#         "id": 2006131,
#         "sunrise": 1657864025,
#         "sunset": 1657900230,
#         "type": 2
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 88,
#         "gust": 9.35,
#         "speed": 7
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 77
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 37.7167,
#         "lon": -25.4333
#     },
#     "dt": 1657879052,
#     "id": 3372472,
#     "main": {
#         "feels_like": 72.21,
#         "grnd_level": 1016,
#         "humidity": 89,
#         "pressure": 1019,
#         "sea_level": 1019,
#         "temp": 71.2,
#         "temp_max": 72.01,
#         "temp_min": 71.2
#     },
#     "name": "Vila Franca do Campo",
#     "sys": {
#         "country": "PT",
#         "id": 37781,
#         "sunrise": 1657866702,
#         "sunset": 1657918995,
#         "type": 2
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 328,
#         "gust": 21.5,
#         "speed": 12.24
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 27
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 13.6017,
#         "lon": 26.6876
#     },
#     "dt": 1657879053,
#     "id": 364933,
#     "main": {
#         "feels_like": 90.99,
#         "grnd_level": 945,
#         "humidity": 42,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 89.74,
#         "temp_max": 89.74,
#         "temp_min": 89.74
#     },
#     "name": "Umm Kaddadah",
#     "sys": {
#         "country": "SD",
#         "sunrise": 1657857202,
#         "sunset": 1657903476
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 217,
#         "gust": 9.73,
#         "speed": 11.39
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 26
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 28.017,
#         "lon": -97.5169
#     },
#     "dt": 1657879053,
#     "id": 4726521,
#     "main": {
#         "feels_like": 84.45,
#         "grnd_level": 1014,
#         "humidity": 78,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 80.24,
#         "temp_max": 86.85,
#         "temp_min": 75.18
#     },
#     "name": "San Patricio",
#     "sys": {
#         "country": "US",
#         "id": 2040001,
#         "sunrise": 1657885399,
#         "sunset": 1657934901,
#         "type": 2
#     },
#     "timezone": -18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 150,
#         "gust": 7.29,
#         "speed": 4.92
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 78.2186,
#         "lon": 15.6401
#     },
#     "dt": 1657879053,
#     "id": 2729907,
#     "main": {
#         "feels_like": 53.62,
#         "humidity": 67,
#         "pressure": 1006,
#         "temp": 55.24,
#         "temp_max": 55.24,
#         "temp_min": 55.24
#     },
#     "name": "Longyearbyen",
#     "sys": {
#         "country": "SJ",
#         "id": 1663,
#         "sunrise": 0,
#         "sunset": 0,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 130,
#         "speed": 13.8
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 81
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -24.7911,
#         "lon": -50.0119
#     },
#     "dt": 1657879053,
#     "id": 3466704,
#     "main": {
#         "feels_like": 54.86,
#         "grnd_level": 903,
#         "humidity": 69,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 56.28,
#         "temp_max": 56.28,
#         "temp_min": 56.28
#     },
#     "name": "Castro",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1657879426,
#         "sunset": 1657918070
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 21,
#         "gust": 18.66,
#         "speed": 6.53
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 36.6167,
#         "lon": 101.7667
#     },
#     "dt": 1657879053,
#     "id": 1788852,
#     "main": {
#         "feels_like": 59.68,
#         "grnd_level": 778,
#         "humidity": 96,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 59.52,
#         "temp_max": 59.52,
#         "temp_min": 59.52
#     },
#     "name": "Xining",
#     "sys": {
#         "country": "CN",
#         "sunrise": 1657836337,
#         "sunset": 1657888300
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "gust": 4,
#         "speed": 2.48
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 38
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 3.0707,
#         "lon": 172.7902
#     },
#     "dt": 1657879053,
#     "id": 2110227,
#     "main": {
#         "feels_like": 89.69,
#         "grnd_level": 1009,
#         "humidity": 81,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 82.26,
#         "temp_max": 82.26,
#         "temp_min": 82.26
#     },
#     "name": "Butaritari",
#     "rain": {
#         "1h": 0.73
#     },
#     "sys": {
#         "country": "KI",
#         "sunrise": 1657823165,
#         "sunset": 1657867378
#     },
#     "timezone": 43200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 113,
#         "gust": 18.75,
#         "speed": 15.73
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 94
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 7.9803,
#         "lon": 49.8164
#     },
#     "dt": 1657879053,
#     "id": 60019,
#     "main": {
#         "feels_like": 92.82,
#         "grnd_level": 1003,
#         "humidity": 50,
#         "pressure": 1007,
#         "sea_level": 1007,
#         "temp": 89.02,
#         "temp_max": 89.02,
#         "temp_min": 89.02
#     },
#     "name": "Eyl",
#     "sys": {
#         "country": "SO",
#         "sunrise": 1657852209,
#         "sunset": 1657897366
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 219,
#         "gust": 36.44,
#         "speed": 26.6
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 18
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -9.8,
#         "lon": -139.0333
#     },
#     "dt": 1657879053,
#     "id": 4020109,
#     "main": {
#         "feels_like": 77.74,
#         "grnd_level": 1006,
#         "humidity": 70,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 77.04,
#         "temp_max": 77.04,
#         "temp_min": 77.04
#     },
#     "name": "Atuona",
#     "sys": {
#         "country": "PF",
#         "sunrise": 1657899232,
#         "sunset": 1657940997
#     },
#     "timezone": -34200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 91,
#         "gust": 13.13,
#         "speed": 13.29
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 71.2906,
#         "lon": -156.7887
#     },
#     "dt": 1657879053,
#     "id": 5880054,
#     "main": {
#         "feels_like": 26.38,
#         "humidity": 80,
#         "pressure": 1013,
#         "temp": 33.82,
#         "temp_max": 33.82,
#         "temp_min": 33.82
#     },
#     "name": "Barrow",
#     "sys": {
#         "country": "US",
#         "id": 7649,
#         "sunrise": 0,
#         "sunset": 0,
#         "type": 1
#     },
#     "timezone": -28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 310,
#         "speed": 9.22
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 93
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 29.2747,
#         "lon": 82.1838
#     },
#     "dt": 1657879054,
#     "id": 1283285,
#     "main": {
#         "feels_like": 70.5,
#         "grnd_level": 774,
#         "humidity": 77,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 70.16,
#         "temp_max": 70.16,
#         "temp_min": 70.16
#     },
#     "name": "Jumla",
#     "sys": {
#         "country": "NP",
#         "sunrise": 1657842094,
#         "sunset": 1657891944
#     },
#     "timezone": 20700,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 222,
#         "gust": 4.61,
#         "speed": 3.36
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 78
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.5322,
#         "lon": 20.0403
#     },
#     "dt": 1657879054,
#     "id": 1015776,
#     "main": {
#         "feels_like": 59.04,
#         "grnd_level": 1017,
#         "humidity": 64,
#         "pressure": 1026,
#         "sea_level": 1026,
#         "temp": 60.3,
#         "temp_max": 60.3,
#         "temp_min": 60.3
#     },
#     "name": "Bredasdorp",
#     "sys": {
#         "country": "ZA",
#         "sunrise": 1657863847,
#         "sunset": 1657900021
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 87,
#         "gust": 9.57,
#         "speed": 7.25
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 42.097,
#         "lon": -79.2353
#     },
#     "dt": 1657879054,
#     "id": 5122534,
#     "main": {
#         "feels_like": 52.12,
#         "humidity": 86,
#         "pressure": 1023,
#         "temp": 53.08,
#         "temp_max": 56.71,
#         "temp_min": 52.52
#     },
#     "name": "Jamestown",
#     "sys": {
#         "country": "US",
#         "id": 2008933,
#         "sunrise": 1657878849,
#         "sunset": 1657932675,
#         "type": 2
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 183,
#         "gust": 1.01,
#         "speed": 1.01
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 74
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -8.19,
#         "lon": 114.9675
#     },
#     "dt": 1657879054,
#     "id": 1650232,
#     "main": {
#         "feels_like": 79.79,
#         "grnd_level": 1008,
#         "humidity": 86,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 78.22,
#         "temp_max": 78.22,
#         "temp_min": 78.22
#     },
#     "name": "Banjar",
#     "sys": {
#         "country": "ID",
#         "sunrise": 1657838116,
#         "sunset": 1657880183
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 152,
#         "gust": 4.27,
#         "speed": 3
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 62
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 22.8909,
#         "lon": -109.9124
#     },
#     "dt": 1657879054,
#     "id": 3985710,
#     "main": {
#         "feels_like": 85.32,
#         "grnd_level": 1009,
#         "humidity": 68,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 81.61,
#         "temp_max": 81.61,
#         "temp_min": 81.61
#     },
#     "name": "Cabo San Lucas",
#     "sys": {
#         "country": "MX",
#         "id": 2005693,
#         "sunrise": 1657888993,
#         "sunset": 1657937257,
#         "type": 2
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 297,
#         "gust": 12.64,
#         "speed": 10.69
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 65.7,
#         "lon": 82.4667
#     },
#     "dt": 1657879025,
#     "id": 1502073,
#     "main": {
#         "feels_like": 62.29,
#         "grnd_level": 1014,
#         "humidity": 48,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 63.95,
#         "temp_max": 63.95,
#         "temp_min": 63.95
#     },
#     "name": "Krasnosel'kup",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1657829518,
#         "sunset": 1657904383
#     },
#     "timezone": 18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 47,
#         "gust": 10.87,
#         "speed": 8.43
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 23
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 50.6789,
#         "lon": 156.125
#     },
#     "dt": 1657879054,
#     "id": 2121385,
#     "main": {
#         "feels_like": 55.17,
#         "grnd_level": 1011,
#         "humidity": 84,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 55.92,
#         "temp_max": 55.92,
#         "temp_min": 55.92
#     },
#     "name": "Severo-Kuril'sk",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1657820345,
#         "sunset": 1657878198
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 273,
#         "gust": 16.51,
#         "speed": 11.54
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 82
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -0.7393,
#         "lon": -90.3518
#     },
#     "dt": 1657879054,
#     "id": 3652764,
#     "main": {
#         "feels_like": 68.61,
#         "humidity": 98,
#         "pressure": 1013,
#         "temp": 67.55,
#         "temp_max": 67.55,
#         "temp_min": 67.55
#     },
#     "name": "Puerto Ayora",
#     "sys": {
#         "country": "EC",
#         "id": 2005652,
#         "sunrise": 1657886686,
#         "sunset": 1657930174,
#         "type": 2
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 137,
#         "gust": 11.01,
#         "speed": 7
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found!
# {
#     "base": "stations",
#     "clouds": {
#         "all": 58
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 41.7597,
#         "lon": 86.1469
#     },
#     "dt": 1657879055,
#     "id": 1529376,
#     "main": {
#         "feels_like": 87.67,
#         "grnd_level": 906,
#         "humidity": 19,
#         "pressure": 1005,
#         "sea_level": 1005,
#         "temp": 91.51,
#         "temp_max": 91.51,
#         "temp_min": 91.51
#     },
#     "name": "Korla",
#     "sys": {
#         "country": "CN",
#         "sunrise": 1657839199,
#         "sunset": 1657892936
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 255,
#         "gust": 11.36,
#         "speed": 11.61
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 60
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -46.6,
#         "lon": 168.3333
#     },
#     "dt": 1657879055,
#     "id": 2206939,
#     "main": {
#         "feels_like": 31.39,
#         "grnd_level": 1006,
#         "humidity": 70,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 38.8,
#         "temp_max": 38.8,
#         "temp_min": 38.8
#     },
#     "name": "Bluff",
#     "sys": {
#         "country": "NZ",
#         "id": 2008959,
#         "sunrise": 1657830342,
#         "sunset": 1657862341,
#         "type": 2
#     },
#     "timezone": 43200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 231,
#         "gust": 14.7,
#         "speed": 11.88
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 66.8333,
#         "lon": 70.8333
#     },
#     "dt": 1657879055,
#     "id": 1486321,
#     "main": {
#         "feels_like": 69.39,
#         "grnd_level": 1015,
#         "humidity": 37,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 70.86,
#         "temp_max": 70.86,
#         "temp_min": 70.86
#     },
#     "name": "Yar-Sale",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1657830289,
#         "sunset": 1657909197
#     },
#     "timezone": 18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "gust": 9.84,
#         "speed": 10.8
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 13.2167,
#         "lon": -59.5167
#     },
#     "dt": 1657879055,
#     "id": 3374083,
#     "main": {
#         "feels_like": 88.84,
#         "humidity": 91,
#         "pressure": 1012,
#         "temp": 81.05,
#         "temp_max": 81.21,
#         "temp_min": 81.05
#     },
#     "name": "Bathsheba",
#     "sys": {
#         "country": "BB",
#         "id": 2017042,
#         "sunrise": 1657877934,
#         "sunset": 1657924125,
#         "type": 2
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 90,
#         "speed": 24.16
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 37.4636,
#         "lon": -122.4286
#     },
#     "dt": 1657879055,
#     "id": 5354943,
#     "main": {
#         "feels_like": 54.86,
#         "humidity": 88,
#         "pressure": 1016,
#         "temp": 55.47,
#         "temp_max": 58.91,
#         "temp_min": 52.65
#     },
#     "name": "Half Moon Bay",
#     "sys": {
#         "country": "US",
#         "id": 4322,
#         "sunrise": 1657890033,
#         "sunset": 1657942225,
#         "type": 1
#     },
#     "timezone": -25200,
#     "visibility": 9656,
#     "weather": [
#         {
#             "description": "mist",
#             "icon": "50n",
#             "id": 701,
#             "main": "Mist"
#         }
#     ],
#     "wind": {
#         "deg": 300,
#         "speed": 9.22
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -38.0023,
#         "lon": -57.5575
#     },
#     "dt": 1657878946,
#     "id": 3430863,
#     "main": {
#         "feels_like": 51.87,
#         "humidity": 98,
#         "pressure": 1011,
#         "temp": 52.34,
#         "temp_max": 53.1,
#         "temp_min": 50.88
#     },
#     "name": "Mar del Plata",
#     "rain": {
#         "1h": 0.4
#     },
#     "sys": {
#         "country": "AR",
#         "id": 268283,
#         "sunrise": 1657882978,
#         "sunset": 1657918140,
#         "type": 2
#     },
#     "timezone": -10800,
#     "visibility": 400,
#     "weather": [
#         {
#             "description": "fog",
#             "icon": "50n",
#             "id": 741,
#             "main": "Fog"
#         },
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 157,
#         "gust": 8.99,
#         "speed": 7
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.918,
#         "lon": 25.5701
#     },
#     "dt": 1657878829,
#     "id": 964420,
#     "main": {
#         "feels_like": 63.3,
#         "humidity": 52,
#         "pressure": 1029,
#         "temp": 64.69,
#         "temp_max": 64.69,
#         "temp_min": 63.1
#     },
#     "name": "Port Elizabeth",
#     "sys": {
#         "country": "ZA",
#         "id": 1973,
#         "sunrise": 1657862435,
#         "sunset": 1657898779,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 330,
#         "speed": 3.44
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -14.5428,
#         "lon": 40.6728
#     },
#     "dt": 1657879055,
#     "id": 1035025,
#     "main": {
#         "feels_like": 83.97,
#         "humidity": 47,
#         "pressure": 1019,
#         "temp": 83.52,
#         "temp_max": 83.52,
#         "temp_min": 83.52
#     },
#     "name": "Nacala",
#     "sys": {
#         "country": "MZ",
#         "id": 2189,
#         "sunrise": 1657856571,
#         "sunset": 1657897393,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 220,
#         "speed": 16.11
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 53.9194,
#         "lon": 58.3672
#     },
#     "dt": 1657879055,
#     "id": 534313,
#     "main": {
#         "feels_like": 71.56,
#         "grnd_level": 952,
#         "humidity": 79,
#         "pressure": 1008,
#         "sea_level": 1008,
#         "temp": 71.04,
#         "temp_max": 71.04,
#         "temp_min": 71.04
#     },
#     "name": "Lomovka",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1657842818,
#         "sunset": 1657902652
#     },
#     "timezone": 18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "gust": 18.79,
#         "speed": 4.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 98
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 22.8833,
#         "lon": 87.7833
#     },
#     "dt": 1657879055,
#     "id": 1278466,
#     "main": {
#         "feels_like": 102.97,
#         "grnd_level": 994,
#         "humidity": 55,
#         "pressure": 997,
#         "sea_level": 997,
#         "temp": 92.64,
#         "temp_max": 92.64,
#         "temp_min": 92.64
#     },
#     "name": "Ar\u0101mb\u0101gh",
#     "rain": {
#         "1h": 0.41
#     },
#     "sys": {
#         "country": "IN",
#         "sunrise": 1657841533,
#         "sunset": 1657889816
#     },
#     "timezone": 19800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 131,
#         "gust": 18.41,
#         "speed": 14.14
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.2,
#         "lon": -175.2
#     },
#     "dt": 1657879056,
#     "id": 4032243,
#     "main": {
#         "feels_like": 77.31,
#         "humidity": 100,
#         "pressure": 1019,
#         "temp": 75.36,
#         "temp_max": 75.36,
#         "temp_min": 75.36
#     },
#     "name": "Vaini",
#     "sys": {
#         "country": "TO",
#         "id": 7285,
#         "sunrise": 1657909067,
#         "sunset": 1657948523,
#         "type": 1
#     },
#     "timezone": 46800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 70,
#         "speed": 5.75
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.9258,
#         "lon": 18.4232
#     },
#     "dt": 1657878983,
#     "id": 3369157,
#     "main": {
#         "feels_like": 62.1,
#         "humidity": 70,
#         "pressure": 1025,
#         "temp": 62.82,
#         "temp_max": 66.11,
#         "temp_min": 58.37
#     },
#     "name": "Cape Town",
#     "sys": {
#         "country": "ZA",
#         "id": 2073005,
#         "sunrise": 1657864150,
#         "sunset": 1657900494,
#         "type": 2
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 190,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 38.4666,
#         "lon": -121.3177
#     },
#     "dt": 1657878997,
#     "id": 5389519,
#     "main": {
#         "feels_like": 63.14,
#         "humidity": 66,
#         "pressure": 1012,
#         "temp": 63.95,
#         "temp_max": 70.93,
#         "temp_min": 58.93
#     },
#     "name": "Sacramento",
#     "sys": {
#         "country": "US",
#         "id": 2002655,
#         "sunrise": 1657889601,
#         "sunset": 1657942124,
#         "type": 2
#     },
#     "timezone": -25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 214,
#         "gust": 5.99,
#         "speed": 1.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 66,
#         "lon": 111.5
#     },
#     "dt": 1657879056,
#     "id": 2027296,
#     "main": {
#         "feels_like": 50.4,
#         "grnd_level": 958,
#         "humidity": 98,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 50.99,
#         "temp_max": 50.99,
#         "temp_min": 50.99
#     },
#     "name": "Aykhal",
#     "rain": {
#         "1h": 0.38
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1657822080,
#         "sunset": 1657897885
#     },
#     "timezone": 32400,
#     "visibility": 2112,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 46,
#         "gust": 26.69,
#         "speed": 14.99
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found!
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -35.1667,
#         "lon": 173.1667
#     },
#     "dt": 1657878796,
#     "id": 2194098,
#     "main": {
#         "feels_like": 52.05,
#         "grnd_level": 1007,
#         "humidity": 82,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 53.19,
#         "temp_max": 53.19,
#         "temp_min": 53.19
#     },
#     "name": "Ahipara",
#     "sys": {
#         "country": "NZ",
#         "sunrise": 1657827198,
#         "sunset": 1657863164
#     },
#     "timezone": 43200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 199,
#         "gust": 8.43,
#         "speed": 6.96
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 89
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 71.6872,
#         "lon": 128.8694
#     },
#     "dt": 1657879056,
#     "id": 2015306,
#     "main": {
#         "feels_like": 35.47,
#         "grnd_level": 1013,
#         "humidity": 81,
#         "pressure": 1018,
#         "sea_level": 1018,
#         "temp": 43.14,
#         "temp_max": 43.14,
#         "temp_min": 43.14
#     },
#     "name": "Tiksi",
#     "sys": {
#         "country": "RU",
#         "sunrise": 0,
#         "sunset": 0
#     },
#     "timezone": 32400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 308,
#         "gust": 21.47,
#         "speed": 16.4
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 11
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 73.5069,
#         "lon": 80.5464
#     },
#     "dt": 1657879056,
#     "id": 1507390,
#     "main": {
#         "feels_like": 37.06,
#         "grnd_level": 1016,
#         "humidity": 79,
#         "pressure": 1021,
#         "sea_level": 1021,
#         "temp": 44.02,
#         "temp_max": 44.02,
#         "temp_min": 44.02
#     },
#     "name": "Dikson",
#     "sys": {
#         "country": "RU",
#         "sunrise": 0,
#         "sunset": 0
#     },
#     "timezone": 25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 41,
#         "gust": 15.17,
#         "speed": 14.79
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 61
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 71.9667,
#         "lon": 102.5
#     },
#     "dt": 1657879056,
#     "id": 2022572,
#     "main": {
#         "feels_like": 61.16,
#         "grnd_level": 1017,
#         "humidity": 39,
#         "pressure": 1020,
#         "sea_level": 1020,
#         "temp": 63.3,
#         "temp_max": 63.3,
#         "temp_min": 63.3
#     },
#     "name": "Khatanga",
#     "sys": {
#         "country": "RU",
#         "sunrise": 0,
#         "sunset": 0
#     },
#     "timezone": 25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 86,
#         "gust": 8.86,
#         "speed": 8.14
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 61
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -6.4167,
#         "lon": 20.8
#     },
#     "dt": 1657879057,
#     "id": 204953,
#     "main": {
#         "feels_like": 89.82,
#         "grnd_level": 959,
#         "humidity": 20,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 93.47,
#         "temp_max": 93.47,
#         "temp_min": 93.47
#     },
#     "name": "Tshikapa",
#     "sys": {
#         "country": "CD",
#         "sunrise": 1657860547,
#         "sunset": 1657902957
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 151,
#         "gust": 8.66,
#         "speed": 7.58
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 95
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 21.6333,
#         "lon": -102.9667
#     },
#     "dt": 1657879057,
#     "id": 4004148,
#     "main": {
#         "feels_like": 63.95,
#         "grnd_level": 864,
#         "humidity": 70,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 64.51,
#         "temp_max": 64.51,
#         "temp_min": 64.51
#     },
#     "name": "Jalpa",
#     "sys": {
#         "country": "MX",
#         "sunrise": 1657887469,
#         "sunset": 1657935447
#     },
#     "timezone": -18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 51,
#         "gust": 4.65,
#         "speed": 4.61
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 88
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 2.8892,
#         "lon": -72.1256
#     },
#     "dt": 1657879057,
#     "id": 3792394,
#     "main": {
#         "feels_like": 72.05,
#         "grnd_level": 992,
#         "humidity": 97,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 70.72,
#         "temp_max": 70.72,
#         "temp_min": 70.72
#     },
#     "name": "Mapirip\u00e1n",
#     "sys": {
#         "country": "CO",
#         "sunrise": 1657881968,
#         "sunset": 1657926143
#     },
#     "timezone": -18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 11,
#         "gust": 5.35,
#         "speed": 3.6
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -53.15,
#         "lon": -70.9167
#     },
#     "dt": 1657879057,
#     "id": 3874787,
#     "main": {
#         "feels_like": 19.18,
#         "humidity": 100,
#         "pressure": 1029,
#         "temp": 26.71,
#         "temp_max": 26.71,
#         "temp_min": 26.71
#     },
#     "name": "Punta Arenas",
#     "sys": {
#         "country": "CL",
#         "id": 8487,
#         "sunrise": 1657889360,
#         "sunset": 1657918171,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 30,
#         "speed": 6.91
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 59.3833,
#         "lon": 143.3
#     },
#     "dt": 1657879058,
#     "id": 2122605,
#     "main": {
#         "feels_like": 60.1,
#         "grnd_level": 1013,
#         "humidity": 95,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 59.94,
#         "temp_max": 59.94,
#         "temp_min": 59.94
#     },
#     "name": "Okhotsk",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1657820098,
#         "sunset": 1657884601
#     },
#     "timezone": 36000,
#     "visibility": 5476,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 188,
#         "gust": 8.57,
#         "speed": 7.38
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -23.8597,
#         "lon": 35.3472
#     },
#     "dt": 1657878950,
#     "id": 1039536,
#     "main": {
#         "feels_like": 75.43,
#         "grnd_level": 1022,
#         "humidity": 47,
#         "pressure": 1025,
#         "sea_level": 1025,
#         "temp": 75.94,
#         "temp_max": 75.94,
#         "temp_min": 75.94
#     },
#     "name": "Maxixe",
#     "sys": {
#         "country": "MZ",
#         "sunrise": 1657858837,
#         "sunset": 1657897684
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 166,
#         "gust": 15.19,
#         "speed": 11.9
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
# ...
#     "clouds": {
#         "all": 83
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 24.6877,
#         "lon": 46.7219
#     },
#     "dt": 1657879031,
#     "id": 108410,
#     "main": {
#         "feels_like": 101.03,
#         "grnd_level": 935,
#         "humidity": 7,
#         "pressure": 998,
#         "sea_level": 998,
#         "temp": 107.74,
#         "temp_max": 107.74,
#         "temp_min": 107.74
#     },
#     "name": "Riyadh",
#     "sys": {
#         "country": "SA",
#         "id": 7424,
#         "sunrise": 1657851179,
#         "sunset": 1657899881,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 1,
#         "gust": 26.46,
#         "speed": 21.14
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 51
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 21.4022,
#         "lon": -157.7394
#     },
#     "dt": 1657879122,
#     "id": 5847486,
#     "main": {
#         "feels_like": 77.99,
#         "humidity": 83,
#         "pressure": 1021,
#         "temp": 76.71,
#         "temp_max": 78.21,
#         "temp_min": 75.43
#     },
#     "name": "Kailua",
#     "sys": {
#         "country": "US",
#         "id": 2043906,
#         "sunrise": 1657814220,
#         "sunset": 1657862176,
#         "type": 2
#     },
#     "timezone": -36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 73,
#         "gust": 11.01,
#         "speed": 5.01
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 10.5,
#         "lon": 10
#     },
#     "dt": 1657879122,
#     "id": 2347468,
#     "main": {
#         "feels_like": 79.12,
#         "grnd_level": 951,
#         "humidity": 71,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 78.26,
#         "temp_max": 78.26,
#         "temp_min": 78.26
#     },
#     "name": "Bauchi",
#     "sys": {
#         "country": "NG",
#         "sunrise": 1657861519,
#         "sunset": 1657907169
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 186,
#         "gust": 5.21,
#         "speed": 4.14
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 42.2506,
#         "lon": -75.833
#     },
#     "dt": 1657879122,
#     "id": 5110365,
#     "main": {
#         "feels_like": 50.83,
#         "humidity": 86,
#         "pressure": 1022,
#         "temp": 51.89,
#         "temp_max": 56.68,
#         "temp_min": 47.08
#     },
#     "name": "Broome",
#     "sys": {
#         "country": "US",
#         "id": 2036074,
#         "sunrise": 1657878003,
#         "sunset": 1657931888,
#         "type": 2
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 147,
#         "gust": 1.99,
#         "speed": 1.01
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 44.804,
#         "lon": 20.4651
#     },
#     "dt": 1657878830,
#     "id": 792680,
#     "main": {
#         "feels_like": 86.88,
#         "humidity": 29,
#         "pressure": 1015,
#         "temp": 89.26,
#         "temp_max": 89.26,
#         "temp_min": 89.04
#     },
#     "name": "Belgrade",
#     "sys": {
#         "country": "RS",
#         "id": 7028,
#         "sunrise": 1657854363,
#         "sunset": 1657909302,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 240,
#         "speed": 3.44
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 81
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 7.4721,
#         "lon": 80.6234
#     },
#     "dt": 1657879122,
#     "id": 1241622,
#     "main": {
#         "feels_like": 88.12,
#         "grnd_level": 967,
#         "humidity": 53,
#         "pressure": 1006,
#         "sea_level": 1006,
#         "temp": 85.59,
#         "temp_max": 85.59,
#         "temp_min": 85.59
#     },
#     "name": "Matale",
#     "sys": {
#         "country": "LK",
#         "sunrise": 1657844863,
#         "sunset": 1657889923
#     },
#     "timezone": 19800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 248,
#         "gust": 22.66,
#         "speed": 10.76
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 17.8833,
#         "lon": 83.4333
#     },
#     "dt": 1657879122,
#     "id": 1275930,
#     "main": {
#         "feels_like": 94.32,
#         "grnd_level": 990,
#         "humidity": 71,
#         "pressure": 998,
#         "sea_level": 998,
#         "temp": 85.51,
#         "temp_max": 85.51,
#         "temp_min": 85.51
#     },
#     "name": "Bh\u012bmunipatnam",
#     "rain": {
#         "1h": 0.16
#     },
#     "sys": {
#         "country": "IN",
#         "id": 9255,
#         "sunrise": 1657843133,
#         "sunset": 1657890305,
#         "type": 1
#     },
#     "timezone": 19800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 257,
#         "gust": 14.56,
#         "speed": 11.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 98
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 9.4942,
#         "lon": 50.8122
#     },
#     "dt": 1657879122,
#     "id": 64814,
#     "main": {
#         "feels_like": 93.63,
#         "grnd_level": 1003,
#         "humidity": 50,
#         "pressure": 1005,
#         "sea_level": 1005,
#         "temp": 89.47,
#         "temp_max": 89.47,
#         "temp_min": 89.47
#     },
#     "name": "Bandarbeyla",
#     "sys": {
#         "country": "SO",
#         "sunrise": 1657851821,
#         "sunset": 1657897275
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 209,
#         "gust": 42.88,
#         "speed": 32.3
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 28.6585,
#         "lon": -17.9182
#     },
#     "dt": 1657879122,
#     "id": 2514651,
#     "main": {
#         "feels_like": 69.76,
#         "humidity": 86,
#         "pressure": 1015,
#         "temp": 69.12,
#         "temp_max": 69.55,
#         "temp_min": 69.12
#     },
#     "name": "Los Llanos de Aridane",
#     "sys": {
#         "country": "ES",
#         "id": 2002582,
#         "sunrise": 1657866207,
#         "sunset": 1657915883,
#         "type": 2
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 30,
#         "speed": 16.11
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found!
# {
#     "base": "stations",
#     "clouds": {
#         "all": 53
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 41.5703,
#         "lon": 120.4586
#     },
#     "dt": 1657879123,
#     "id": 2038120,
#     "main": {
#         "feels_like": 83.82,
#         "grnd_level": 981,
#         "humidity": 57,
#         "pressure": 999,
#         "sea_level": 999,
#         "temp": 81.95,
#         "temp_max": 81.95,
#         "temp_min": 81.95
#     },
#     "name": "Chaoyang",
#     "sys": {
#         "country": "CN",
#         "sunrise": 1657830995,
#         "sunset": 1657884669
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 11,
#         "gust": 17.85,
#         "speed": 11.18
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 67
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -9.2,
#         "lon": 25.85
#     },
#     "dt": 1657879123,
#     "id": 217834,
#     "main": {
#         "feels_like": 85.1,
#         "grnd_level": 948,
#         "humidity": 26,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 87.98,
#         "temp_max": 87.98,
#         "temp_min": 87.98
#     },
#     "name": "Bukama",
#     "sys": {
#         "country": "CD",
#         "sunrise": 1657859602,
#         "sunset": 1657901477
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 133,
#         "gust": 6.46,
#         "speed": 3.76
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 41
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 62.7161,
#         "lon": 129.6658
#     },
#     "dt": 1657879123,
#     "id": 2019488,
#     "main": {
#         "feels_like": 78.08,
#         "grnd_level": 1000,
#         "humidity": 59,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 77.83,
#         "temp_max": 77.83,
#         "temp_min": 77.83
#     },
#     "name": "Namtsy",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1657821244,
#         "sunset": 1657890000
#     },
#     "timezone": 32400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 37,
#         "gust": 6.13,
#         "speed": 4.61
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 95
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -31.6333,
#         "lon": -60.7
#     },
#     "dt": 1657878861,
#     "id": 3836277,
#     "main": {
#         "feels_like": 51.69,
#         "humidity": 91,
#         "pressure": 1004,
#         "temp": 52.47,
#         "temp_max": 54.01,
#         "temp_min": 50.92
#     },
#     "name": "Santa Fe",
#     "sys": {
#         "country": "AR",
#         "id": 2008823,
#         "sunrise": 1657882826,
#         "sunset": 1657919801,
#         "type": 2
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 169,
#         "gust": 17,
#         "speed": 8.01
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 68
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 14.2526,
#         "lon": -5.993
#     },
#     "dt": 1657879123,
#     "id": 2452655,
#     "main": {
#         "feels_like": 94.39,
#         "grnd_level": 980,
#         "humidity": 38,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 92.89,
#         "temp_max": 92.89,
#         "temp_min": 92.89
#     },
#     "name": "Niono",
#     "sys": {
#         "country": "ML",
#         "sunrise": 1657864980,
#         "sunset": 1657911385
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 10,
#         "gust": 8.21,
#         "speed": 8.55
#     }
# }
# [{'City': 'kambove', 'Lat': -10.8764, 'Lng': 26.5969, 'Max_Temp': 75.07, 'Humidity': 35, 'Cloudness': 8, 'WindSpeed': 7.02, 'Country': 'CD', 'Date': 1657879051}, {'City': 'nanortalik', 'Lat': 60.1432, 'Lng': -45.2371, 'Max_Temp': 43.68, 'Humidity': 83, 'Cloudness': 100, 'WindSpeed': 0.65, 'Country': 'GL', 'Date': 1657879051}, {'City': 'kodiak', 'Lat': 57.79, 'Lng': -152.4072, 'Max_Temp': 54.66, 'Humidity': 91, 'Cloudness': 90, 'WindSpeed': 3.98, 'Country': 'US', 'Date': 1657879051}, {'City': 'cherskiy', 'Lat': 68.75, 'Lng': 161.3, 'Max_Temp': 49.89, 'Humidity': 54, 'Cloudness': 99, 'WindSpeed': 7.23, 'Country': 'RU', 'Date': 1657879051}, {'City': 'mataura', 'Lat': -46.1927, 'Lng': 168.8643, 'Max_Temp': 38.48, 'Humidity': 98, 'Cloudness': 98, 'WindSpeed': 2.86, 'Country': 'NZ', 'Date': 1657879051}, {'City': 'sandane', 'Lat': 61.7728, 'Lng': 6.215, 'Max_Temp': 56.57, 'Humidity': 71, 'Cloudness': 75, 'WindSpeed': 2.3, 'Country': 'NO', 'Date': 1657879039}, {'City': 'conde', 'Lat': -7.2597, 'Lng': -34.9075, 'Max_Temp': 69.26, 'Humidity': 100, 'Cloudness': 75, 'WindSpeed': 8.05, 'Country': 'BR', 'Date': 1657879051}, {'City': 'ushuaia', 'Lat': -54.8, 'Lng': -68.3, 'Max_Temp': 24.46, 'Humidity': 80, 'Cloudness': 0, 'WindSpeed': 1.14, 'Country': 'AR', 'Date': 1657878909}, {'City': 'albany', 'Lat': 42.6001, 'Lng': -73.9662, 'Max_Temp': 58.73, 'Humidity': 86, 'Cloudness': 1, 'WindSpeed': 3.44, 'Country': 'US', 'Date': 1657879052}, {'City': 'ancud', 'Lat': -41.8697, 'Lng': -73.8203, 'Max_Temp': 38.23, 'Humidity': 83, 'Cloudness': 33, 'WindSpeed': 8.66, 'Country': 'CL', 'Date': 1657879052}, {'City': 'kendari', 'Lat': -3.945, 'Lng': 122.4989, 'Max_Temp': 73.69, 'Humidity': 96, 'Cloudness': 100, 'WindSpeed': 0.29, 'Country': 'ID', 'Date': 1657879052}, {'City': 'rikitea', 'Lat': -23.1203, 'Lng': -134.9692, 'Max_Temp': 67.21, 'Humidity': 77, 'Cloudness': 100, 'WindSpeed': 8.3, 'Country': 'PF', 'Date': 1657879052}, {'City': 'hobart', 'Lat': -42.8794, 'Lng': 147.3294, 'Max_Temp': 46.26, 'Humidity': 83, 'Cloudness': 75, 'WindSpeed': 5.75, 'Country': 'AU', 'Date': 1657879052}, {'City': 'hermanus', 'Lat': -34.4187, 'Lng': 19.2345, 'Max_Temp': 60.8, 'Humidity': 69, 'Cloudness': 97, 'WindSpeed': 7, 'Country': 'ZA', 'Date': 1657879052}, {'City': 'vila franca do campo', 'Lat': 37.7167, 'Lng': -25.4333, 'Max_Temp': 72.01, 'Humidity': 89, 'Cloudness': 77, 'WindSpeed': 12.24, 'Country': 'PT', 'Date': 1657879052}, {'City': 'umm kaddadah', 'Lat': 13.6017, 'Lng': 26.6876, 'Max_Temp': 89.74, 'Humidity': 42, 'Cloudness': 27, 'WindSpeed': 11.39, 'Country': 'SD', 'Date': 1657879053}, {'City': 'san patricio', 'Lat': 28.017, 'Lng': -97.5169, 'Max_Temp': 86.85, 'Humidity': 78, 'Cloudness': 26, 'WindSpeed': 4.92, 'Country': 'US', 'Date': 1657879053}, {'City': 'longyearbyen', 'Lat': 78.2186, 'Lng': 15.6401, 'Max_Temp': 55.24, 'Humidity': 67, 'Cloudness': 75, 'WindSpeed': 13.8, 'Country': 'SJ', 'Date': 1657879053}, {'City': 'castro', 'Lat': -24.7911, 'Lng': -50.0119, 'Max_Temp': 56.28, 'Humidity': 69, 'Cloudness': 81, 'WindSpeed': 6.53, 'Country': 'BR', 'Date': 1657879053}, {'City': 'xining', 'Lat': 36.6167, 'Lng': 101.7667, 'Max_Temp': 59.52, 'Humidity': 96, 'Cloudness': 100, 'WindSpeed': 2.48, 'Country': 'CN', 'Date': 1657879053}, {'City': 'butaritari', 'Lat': 3.0707, 'Lng': 172.7902, 'Max_Temp': 82.26, 'Humidity': 81, 'Cloudness': 38, 'WindSpeed': 15.73, 'Country': 'KI', 'Date': 1657879053}, {'City': 'eyl', 'Lat': 7.9803, 'Lng': 49.8164, 'Max_Temp': 89.02, 'Humidity': 50, 'Cloudness': 94, 'WindSpeed': 26.6, 'Country': 'SO', 'Date': 1657879053}, {'City': 'atuona', 'Lat': -9.8, 'Lng': -139.0333, 'Max_Temp': 77.04, 'Humidity': 70, 'Cloudness': 18, 'WindSpeed': 13.29, 'Country': 'PF', 'Date': 1657879053}, {'City': 'barrow', 'Lat': 71.2906, 'Lng': -156.7887, 'Max_Temp': 33.82, 'Humidity': 80, 'Cloudness': 100, 'WindSpeed': 9.22, 'Country': 'US', 'Date': 1657879053}, {'City': 'jumla', 'Lat': 29.2747, 'Lng': 82.1838, 'Max_Temp': 70.16, 'Humidity': 77, 'Cloudness': 93, 'Wi ...

# %%
# Get weather data
#weather_response = requests.get(query_url)
#weather_json = weather_response.json()
#print(json.dumps(weather_json, indent=4, sort_keys=True))

# %%
#weather_json["wind"]["speed"]

# %% [markdown]
# # Converting Raw Data to DataFrame¶

# %%
city_weather_pd = pd.DataFrame(city_weather)
city_weather_pd.head()
# Out:
#          City      Lat       Lng  Max_Temp  Humidity  Cloudness  WindSpeed  \
# 0     kambove -10.8764   26.5969     75.07        35          8       7.02
# 1  nanortalik  60.1432  -45.2371     43.68        83        100       0.65
# 2      kodiak  57.7900 -152.4072     54.66        91         90       3.98
# 3    cherskiy  68.7500  161.3000     49.89        54         99       7.23
# 4     mataura -46.1927  168.8643     38.48        98         98       2.86
#
#   Country        Date
# 0      CD  1657879051
# 1      GL  1657879051
# 2      US  1657879051
# 3      RU  1657879051
# 4      NZ  1657879051

# %%
city_weather_pd.shape
# Out:
# (580, 9)

# %%
#Exporting the city data into a .csv.
city_weather_pd.to_csv("weather_json.csv")

# %%
#Displaying city data from csv file

city_weather_complete = pd.read_csv("weather_json.csv", index_col=0)

# %%
city_weather_complete.head()
# Out:
#          City      Lat       Lng  Max_Temp  Humidity  Cloudness  WindSpeed  \
# 0     kambove -10.8764   26.5969     75.07        35          8       7.02
# 1  nanortalik  60.1432  -45.2371     43.68        83        100       0.65
# 2      kodiak  57.7900 -152.4072     54.66        91         90       3.98
# 3    cherskiy  68.7500  161.3000     49.89        54         99       7.23
# 4     mataura -46.1927  168.8643     38.48        98         98       2.86
#
#   Country        Date
# 0      CD  1657879051
# 1      GL  1657879051
# 2      US  1657879051
# 3      RU  1657879051
# 4      NZ  1657879051

# %%
#Inspect the data and remove the cities where the humidity > 100%.

humidity_df = city_weather_complete.describe(include = "all")

# %%
humidity_df.drop(['City','Country'], axis=1, inplace=True)

# %%
humidity_df.drop(['unique','top', 'freq'], axis=0, inplace=True)

# %%
humidity_df
# Out:
#               Lat         Lng    Max_Temp    Humidity   Cloudness   WindSpeed  \
# count  580.000000  580.000000  580.000000  580.000000  580.000000  580.000000
# mean    20.055716   18.479935   70.622379   68.024138   58.817241    7.998414
# std     32.848392   88.487260   14.677444   22.710450   37.543725    5.287609
# min    -54.800000 -175.200000   24.460000    1.000000    0.000000    0.000000
# 25%     -6.320700  -58.866825   59.992500   53.000000   20.750000    3.865000
# 50%     21.374550   23.895050   72.020000   73.500000   73.000000    7.110000
# 75%     48.829775   91.918925   80.940000   86.000000   97.250000   11.015000
# max     78.218600  179.316700  111.150000  100.000000  100.000000   32.300000
#
#                Date
# count  5.800000e+02
# mean   1.657879e+09
# std    6.070221e+01
# min    1.657879e+09
# 25%    1.657879e+09
# 50%    1.657879e+09
# 75%    1.657879e+09
# max    1.657879e+09

# %% [markdown]
# # Plotting the Data

# %%
# Latitude vs. Temperature Plot
today = time.strftime("%d/%m/%Y")
city_lat = city_weather_complete['Lat']
max_temp = city_weather_complete['Max_Temp']
plt.scatter(city_lat, max_temp, marker= "o", color="red", alpha=0.75,edgecolors="blue")
plt.xlabel("City Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs Max Temperature ({today})")
plt.savefig('lat_vs_temp.png')
plt.show()

# %%
#Latitude vs. Humidity Plot
today = time.strftime("%d/%m/%Y")
city_lat = city_weather_complete['Lat']
humidity = city_weather_complete['Humidity']
plt.scatter(city_lat, humidity, marker= "o", color="red", alpha=0.75,edgecolors="green")
plt.xlabel("City Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity ({today})")
plt.savefig('lat_vs_hum.png')
plt.show()

# %%
# Latitude vs. Wind Speed Plot
today = time.strftime("%d/%m/%Y")
city_lat = city_weather_complete['Lat']
wind_speed = city_weather_complete['WindSpeed']
plt.scatter(city_lat, wind_speed, marker= "o", color="red", alpha=0.75,edgecolors="blue")
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed (%)")
plt.title(f"City Latitude vs Wind Speed ({today})")
plt.savefig('lat_vs_wind.png')
plt.show()

# %%
# Latitude vs. Cloudiness Plot
today = time.strftime("%d/%m/%Y")
city_lat = city_weather_complete['Lat']
cloudness = city_weather_complete['Cloudness']
plt.scatter(city_lat, cloudness, marker= "o", color="red", alpha=0.75,edgecolors="blue")
plt.xlabel("City Latitude")
plt.ylabel("Cloudness (%)")
plt.title(f"City Latitude vs Cloudness ({today})")
plt.savefig('lat_vs_cloud.png')
plt.show()

# %% [markdown]
# # Linear Regression

# %% [markdown]
# # Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Calculating the number of Cities in the Northern Hemisphere
northern_hemisphere_df = city_weather_complete.loc[city_weather_complete["Lat"] > 0]
northern_cities_count = len(northern_hemisphere_df)

# %%
northern_cities_count
# Out:
# 405

# %%
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = northern_hemisphere_df['Lat']
y_values = northern_hemisphere_df['Max_Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=10,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
print(f"The r-value is: {rvalue}")
plt.savefig('nrth_hemisphere- lat_vs_max_tem.png')
plt.show()
# Out:
# The r-value is: -0.6330442985814447

# %% [markdown]
# # Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Calculating the number of Cities in the Southern Hemisphere 
southern_hemisphere_df = city_weather_complete.loc[city_weather_complete["Lat"] < 0]
southern_cities_count = len(southern_hemisphere_df)

# %%
southern_cities_count
# Out:
# 175

# %%
#Southern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = southern_hemisphere_df['Lat']
y_values = southern_hemisphere_df['Max_Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=10,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
print(f"The r-value is: {rvalue}")
plt.savefig('sthn_hemisphere- lat_vs_max_tem.png')
plt.show()
# Out:
# The r-value is: 0.7682872469818516

# %% [markdown]
# # Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = northern_hemisphere_df['Lat']
y_values = northern_hemisphere_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=10,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-value is: {rvalue}")
plt.savefig('nrth_hemisphere- hum_vs_lat.png')
plt.show()
# Out:
# The r-value is: -0.061474215158000924

# %% [markdown]
# # Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = southern_hemisphere_df['Lat']
y_values = southern_hemisphere_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=10,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-value is: {rvalue}")
plt.savefig('sthn_hemisphere- lat_vs_hum.png')
plt.show()
# Out:
# The r-value is: -0.005887905319471711

# %% [markdown]
# # Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Cloudness (%) vs. Latitude Linear Regression
x_values = northern_hemisphere_df['Lat']
y_values = northern_hemisphere_df['Cloudness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=10,color="orange")
plt.xlabel('Latitude')
plt.ylabel('Cloudness (%)')
print(f"The r-value is: {rvalue}")
plt.savefig('nrth_hemisphere- cldness_vs_lat.png')
plt.show()
# Out:
# The r-value is: -0.10287776723569876

# %% [markdown]
# # Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Cloudness (%) vs. Latitude Linear Regression
x_values = southern_hemisphere_df['Lat']
y_values = southern_hemisphere_df['Cloudness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=10,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudness (%)')
print(f"The r-value is: {rvalue}")
plt.savefig('sthn_hemisphere- lat_vs_cldness.png')
plt.show()
# Out:
# The r-value is: -0.045073535172358445

# %% [markdown]
# # Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = northern_hemisphere_df['Lat']
y_values = northern_hemisphere_df['WindSpeed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=10,color="orange")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The r-value is: {rvalue}")
plt.savefig('nrth_hemisphere- windsp_vs_lat.png')
plt.show()
# Out:
# The r-value is: -0.0481836599449572

# %% [markdown]
# # Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = southern_hemisphere_df['Lat']
y_values = southern_hemisphere_df['WindSpeed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=10,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The r-value is: {rvalue}")
plt.savefig('sthn_hemisphere- lat_vs_windsp.png')
plt.show()
# Out:
# The r-value is: -0.039771237925445034
